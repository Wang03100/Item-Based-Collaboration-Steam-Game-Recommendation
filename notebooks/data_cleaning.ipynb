# %%
import pandas as pd
import json
import numpy as np
import requests
import time

rec = pd.read_csv('../data/recommendations.csv')

# %% [markdown]
# # Column Cleaning Data

# %%
# is_recommended only has true
rec = rec.loc[rec['is_recommended']]
# removing unneeded columns
rec = rec[['app_id', 'user_id']]
# Check for Null values in data
print(f"Checking Rec for Nulls ================== \n{rec.isnull().sum()}")
# Out:
# Checking Rec for Nulls ==================
# app_id     0
# user_id    0
# dtype: int64

# %% [markdown]
# # Basic Pandas Overviewing

# %%
print(f"Random 5 Values:  ==========\n {rec.sample(5)}")
print(f"Columns: =========== \n {rec.columns}")
print(f"Column Data Types: ============ \n {rec.info()}")
print(f"Shape: ============= \n {rec.shape}")
# Out:
# Random 5 Values:  ==========
#             app_id   user_id
# 17345459   231430   6208732
# 16719118   629520   1934141
# 18649600   584400   5557257
# 19969308   444090   8640524
# 38121591  1094960  11170906
# Columns: ===========
#  Index(['app_id', 'user_id'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 35304398 entries, 0 to 41154793
# Data columns (total 2 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   app_id   int64
#  1   user_id  int64
# dtypes: int64(2)
# memory usage: 808.1 MB
# Column Data Types: ============
#  None
# Shape: =============
#  (35304398, 2)

# %% [markdown]
# # Data Overview

# %%
unique_users = rec["user_id"].nunique()
unique_games = rec["app_id"].nunique()
total_len = len(rec)
print(f"Unique Users: =============== \n {unique_users} of {total_len} | {unique_users / total_len * 100}%")
print(f"Unique Games: =============== \n {unique_games} of{total_len} | {unique_games / total_len * 100}%")

# Value Counts:
user_activity = rec['user_id'].value_counts()
print(f"User Value Count: ====================== \n {user_activity}")
game_popularity = rec['app_id'].value_counts()
print(f"Game Value Count: ====================== \n {game_popularity}")

# Users: How many games per user?
print("Games per user - statistics: ====================== \n ")
print(user_activity.describe())


# Games: How many users per game?
print("\nUsers per game - statistics: ====================== \n ")  
print(game_popularity.describe())

# Find most active users and popular games
print(f"\nMost active user has {user_activity.max()} interactions")
print(f"Most popular game has {game_popularity.max()} users")

# User Distribution
print("User activity distribution: ====================== \n ")
print(f"Users with 1 game: ====================== \n {(user_activity == 1).sum():,}")
print(f"Users with 2-4 games: ====================== \n {((user_activity >= 2) & (user_activity <= 4)).sum():,}")
print(f"Users with 5+ games: ====================== \n {(user_activity >= 5).sum():,}")
print(f"Users with 10+ games: ====================== \n {(user_activity >= 10).sum():,}")

# Game Distribution
print("\nGame popularity distribution: ====================== \n ")
print(f"Games with 1 user: ====================== \n {(game_popularity == 1).sum():,}")
print(f"Games with 2 users: ====================== \n {((game_popularity == 2)).sum():,}")
print(f"Games with 3 users: ====================== \n {(game_popularity == 3).sum():,}")
print(f"Games with 4 users: ====================== \n {(game_popularity == 4).sum():,}")
print(f"Games with 50+ users: ====================== \n {(game_popularity >= 50).sum():,}")
# Out:
# Unique Users: ===============
#  12663134 of 35304398 | 35.8684320293466%
# Unique Games: ===============
#  37419 of35304398 | 0.10598962769454388%
# User Value Count: ======================
#  user_id
# 5112758     3920
# 5669734     3479
# 11553593    3392
# 5390510     3023
# 1353327     2262
#             ...
# 10056071       1
# 10310667       1
# 7057335        1
# 13132997       1
# 2306695        1
# Name: count, Length: 12663134, dtype: int64
# Game Value Count: ======================
#  app_id
# 440        294879
# 252490     226293
# 292030     193139
# 431960     186792
# 730        186306
#             ...
# 1554670         1
# 1098790         1
# 886670          1
# 1840510         1
# 1687020         1
# Name: count, Length: 37419, dtype: int64
# Games per user - statistics: ======================
#
# count    1.266313e+07
# mean     2.787967e+00
# std      6.757650e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      3.000000e+00
# max      3.920000e+03
# Name: count, dtype: float64
#
# Users per game - statistics: ======================
#
# count     37419.000000
# mean        943.488549
# std        6725.926600
# min           1.000000
# 25%          10.000000
# 50%          29.000000
# 75%         139.000000
# max      294879.000000
# Name: count, dtype: float64
#
# Most active user has 3920 interactions
# Most popular game has 294879 users
# User activity distribution: ======================
#
# Users with 1 game: ======================
#  7,115,071
# Users with 2-4 games: ======================
#  3,923,997
# Users with 5+ games: ======================
#  1,624,066
# Users with 10+ games: ======================
#  548,339
#
# Game popularity distribution: ======================
#
# Games with 1 user: ======================
#  630
# Games with 2 users: ======================
#  874
# Games with 3 users: ======================
#  1,085
# Games with 4 users: ======================
#  1,126
# Games with 50+ users: ======================
#  14,890

# %% [markdown]
# # Data Cleaning

# %%
# Filter 1: Remove users with too few games
min_user_games = 5  # Users must have recommended at least 5 games
filtered_active_users = user_activity[user_activity >= min_user_games].index
filtered_rec = rec[rec['user_id'].isin(filtered_active_users)]

# Filter 2: Remove unpopular games  
min_game_users = 15  # Games must have at least 15 users
filtered_game_popularity = filtered_rec['app_id'].value_counts()
popular_games = filtered_game_popularity[filtered_game_popularity >= min_game_users].index
filtered_rec = filtered_rec[filtered_rec['app_id'].isin(popular_games)]

# Value Counts:
filtered_user_activity = filtered_rec['user_id'].value_counts()
filtered_game_popularity = filtered_rec['app_id'].value_counts()
print(f"User Distribution: ====================== \n {filtered_user_activity.describe()}")
print(f"Game Distribution: ====================== \n {filtered_game_popularity.describe()}")

# User Distribution
print("User activity distribution: ====================== \n ")
print(f"Users with 1-3 games: ====================== (Values Are From Game Filter Downgrade)\n {((filtered_user_activity >= 1) & (filtered_user_activity <= 3)).sum():,}")
print(f"Users with 4+ games: ====================== \n {(filtered_user_activity >= 4).sum():,}")

# Game Distribution
print("\nGame popularity distribution: ====================== \n ")
print(f"Games with 1-9 users: ====================== \n {((filtered_game_popularity >= 1) & (filtered_game_popularity < 10)).sum():,}")
print(f"Games with 10+ users: ====================== \n {(filtered_game_popularity >= 10).sum():,}")

rec = filtered_rec.copy()
# Out:
# User Distribution: ======================
#  count    1.624058e+06
# mean     1.105287e+01
# std      1.554495e+01
# min      1.000000e+00
# 25%      6.000000e+00
# 50%      7.000000e+00
# 75%      1.100000e+01
# max      3.073000e+03
# Name: count, dtype: float64
# Game Distribution: ======================
#  count     22214.000000
# mean        808.071441
# std        3707.323929
# min          15.000000
# 25%          29.000000
# 50%          71.000000
# 75%         264.000000
# max      115244.000000
# Name: count, dtype: float64
# User activity distribution: ======================
#
# Users with 1-3 games: ====================== (Values Are From Game Filter Downgrade)
#  374
# Users with 4+ games: ======================
#  1,623,684
#
# Game popularity distribution: ======================
#
# Games with 1-9 users: ======================
#  0
# Games with 10+ users: ======================
#  22,214

# %% [markdown]
# # Query Around

# %%
print(f"Finding Which User Recommended Team Fortress 2 ============================\n{rec.query('app_id == 440')}")
print(f"Shape of it ============================\n{rec.query('app_id == 440').shape}")
# Out:
# Finding Which User Recommended Team Fortress 2 ============================
#           app_id   user_id
# 7102         440   4327329
# 12403        440  11692274
# 13725        440  11216854
# 14766        440  12522295
# 18053        440  12052932
# ...          ...       ...
# 33843171     440   3633082
# 33854538     440  11431931
# 33866199     440   7844778
# 33866861     440   5643333
# 33912772     440     27749
#
# [115244 rows x 2 columns]
# Shape of it ============================
# (115244, 2)

# %% [markdown]
# # Getting SteamSpy Game Data

# %%
def collect_steamspy_data_paginated(target_game_ids, max_pages=None, delay=1.0, start_page=0):
    """
    Collect SteamSpy data using paginated API calls
    
    Args:
        target_game_ids: set of app_ids we need metadata for
        max_pages: maximum pages to fetch (None for all)
        delay: seconds between requests
        start_page: starting page number (default 0)
    """
    collected_games = {}
    found_target_games = set()
    page = start_page - 1  # Will be incremented to start_page in first iteration
    
    print(f"Looking for {len(target_game_ids):,} target games...")
    print(f"Starting paginated collection from page {start_page}...")
    
    while True:
        page += 1
        print(f"\nProcessing page {page}...")
        
        try:
            # Make API request
            url = f"https://steamspy.com/api.php?request=all&page={page}"
            response = requests.get(url, timeout=15)
            
            if response.status_code != 200:
                print(f"HTTP {response.status_code} on page {page}")
                if response.status_code == 429:  # Rate limited
                    print("Rate limited - waiting 10 seconds...")
                    time.sleep(10)
                    continue
                else:
                    break
                
            # Parse JSON response
            page_data = response.json()
            
            # Check if page is empty (end of data)
            if not page_data or len(page_data) == 0:
                print("Empty page - reached end of data")
                break
                
            print(f"Got {len(page_data)} games on page {page}")
            
            # Filter for games
            page_matches = 0
            for app_id_str, game_data in page_data.items():
                try:
                    app_id_int = int(app_id_str)
                    if app_id_int in target_game_ids:
                        # Only keep games with essential data
                        if game_data.get('name') and game_data.get('name').strip():
                            collected_games[app_id_str] = game_data
                            found_target_games.add(app_id_int)
                            page_matches += 1
                except (ValueError, TypeError):
                    continue  # Skip invalid app_ids
            
            print(f"Found {page_matches} target games with valid data on this page")
            print(f"Total collected: {len(collected_games):,}")
            print(f"Progress: {len(found_target_games)}/{len(target_game_ids)} ({len(found_target_games)/len(target_game_ids)*100:.1f}%)")
            
            # Save progress periodically
            if page % 20 == 0:
                with open(f'../data/steamspy_progress_page_{page}.json', 'w') as f:
                    json.dump(collected_games, f)
                print(f"Saved progress at page {page}")
                
            # Respect max_pages limit
            if max_pages and page >= max_pages:
                print(f"Reached max_pages limit ({max_pages})")
                break
                
        except Exception as e:
            print(f"Error on page {page}: {e}")
            print("Waiting 5 seconds before retry...")
            time.sleep(5)
            continue
            
        # Be respectful to the API
        time.sleep(delay)
    
    print(f"\n=== COLLECTION COMPLETE ===")
    print(f"Pages processed: {page}")
    print(f"Games collected: {len(collected_games):,}")
    print(f"Target games found: {len(found_target_games):,}/{len(target_game_ids):,}")
    print(f"Final coverage: {len(found_target_games)/len(target_game_ids)*100:.1f}%")
    
    return collected_games, found_target_games

# %%
target_game_ids = set(rec['app_id'].unique())
print(f"Target games needed: {len(target_game_ids):,}")

# Full collection
full_data, found_games = collect_steamspy_data_paginated(
    target_game_ids=target_game_ids,
    max_pages=100,
    start_page=0
)
# Out:
# Target games needed: 22,214
# Looking for 22,214 target games...
# Starting paginated collection from page 0...
#
# Processing page 0...
# Got 1000 games on page 0
# Found 851 target games with valid data on this page
# Total collected: 851
# Progress: 851/22214 (3.8%)
# Saved progress at page 0
#
# Processing page 1...
# Got 1000 games on page 1
# Found 817 target games with valid data on this page
# Total collected: 1,668
# Progress: 1668/22214 (7.5%)
#
# Processing page 2...
# Got 1000 games on page 2
# Found 809 target games with valid data on this page
# Total collected: 2,477
# Progress: 2477/22214 (11.2%)
#
# Processing page 3...
# Got 1000 games on page 3
# Found 783 target games with valid data on this page
# Total collected: 3,259
# Progress: 3259/22214 (14.7%)
#
# Processing page 4...
# Got 1000 games on page 4
# Found 749 target games with valid data on this page
# Total collected: 4,007
# Progress: 4007/22214 (18.0%)
#
# Processing page 5...
# Got 1000 games on page 5
# Found 756 target games with valid data on this page
# Total collected: 4,760
# Progress: 4760/22214 (21.4%)
#
# Processing page 6...
# Got 1000 games on page 6
# Found 692 target games with valid data on this page
# Total collected: 5,449
# Progress: 5449/22214 (24.5%)
#
# Processing page 7...
# Got 1000 games on page 7
# Found 703 target games with valid data on this page
# Total collected: 6,148
# Progress: 6148/22214 (27.7%)
#
# Processing page 8...
# Got 1000 games on page 8
# Found 663 target games with valid data on this page
# Total collected: 6,804
# Progress: 6804/22214 (30.6%)
#
# Processing page 9...
# Got 1000 games on page 9
# Found 629 target games with valid data on this page
# Total collected: 7,422
# Progress: 7422/22214 (33.4%)
#
# Processing page 10...
# Got 1000 games on page 10
# Found 574 target games with valid data on this page
# Total collected: 7,988
# Progress: 7988/22214 (36.0%)
#
# Processing page 11...
# Got 1000 games on page 11
# Found 592 target games with valid data on this page
# Total collected: 8,566
# Progress: 8566/22214 (38.6%)
#
# Processing page 12...
# Got 1000 games on page 12
# Found 526 target games with valid data on this page
# Total collected: 9,090
# Progress: 9090/22214 (40.9%)
#
# Processing page 13...
# Got 1000 games on page 13
# Found 542 target games with valid data on this page
# Total collected: 9,631
# Progress: 9631/22214 (43.4%)
#
# Processing page 14...
# Got 1000 games on page 14
# Found 535 target games with valid data on this page
# Total collected: 10,136
# Progress: 10136/22214 (45.6%)
#
# Processing page 15...
# Got 1000 games on page 15
# Found 517 target games with valid data on this page
# Total collected: 10,647
# Progress: 10647/22214 (47.9%)
#
# Processing page 16...
# Got 1000 games on page 16
# Found 493 target games with valid data on this page
# Total collected: 11,130
# Progress: 11130/22214 (50.1%)
#
# Processing page 17...
# Got 1000 games on page 17
# Found 451 target games with valid data on this page
# Total collected: 11,541
# Progress: 11541/22214 (52.0%)
#
# Processing page 18...
# Got 1000 games on page 18
# Found 437 target games with valid data on this page
# Total collected: 11,967
# Progress: 11967/22214 (53.9%)
#
# Processing page 19...
# Got 1000 games on page 19
# Found 397 target games with valid data on this page
# Total collected: 12,353
# Progress: 12353/22214 (55.6%)
#
# Processing page 20...
# Got 1000 games on page 20
# Found 403 target games with valid data on this page
# Total collected: 12,714
# Progress: 12714/22214 (57.2%)
# Saved progress at page 20
#
# Processing page 21...
# Got 1000 games on page 21
# Found 404 target games with valid data on this page
# Total collected: 13,117
# Progress: 13117/22214 (59.0%)
#
# Processing page 22...
# Got 1000 games on page 22
# Found 364 target games with valid data on this page
# Total collected: 13,477
# Progress: 13477/22214 (60.7%)
#
# Processing page 23...
# Got 1000 games on page 23
# Found 353 target games with valid data on this page
# Total collected: 13,818
# Progress: 13818/22214 (62.2%)
#
# Processing page 24...
# Got 1000 games on page 24
# Found 324 target games with valid data on this page
# Total collected: 14,092
# Progress: 14092/22214 (63.4%)
#
# Processing page 25...
# Got 1000 games on page 25
# Found 342 target games with valid data on this page
# Total collected: 14,421
# Progress: 14421/22214 (64.9%)
#
# Processing page 26...
# Got 1000 games on page 26
# Found 356 target games with valid data on this page
# Total collected: 14,714
# Progress: 14714/22214 (66.2%)
#
# Processing page 27...
# Got 1000 games on page 27
# Found 293 target games with valid data on this page
# Total collected: 15,002
# Progress: 15002/22214 (67.5%)
#
# Processing page 28...
# Got 1000 games on page 28
# Found 305 target games with valid data on this page
# Total collected: 15,275
# Progress: 15275/22214 (68.8%)
#
# Processing page 29...
# Got 1000 games on page 29
# Found 247 target games with valid data on this page
# Total collected: 15,481
# Progress: 15481/22214 (69.7%)
#
# Processing page 30...
# Got 1000 games on page 30
# Found 248 target games with valid data on this page
# Total collected: 15,725
# Progress: 15725/22214 (70.8%)
#
# Processing page 31...
# Got 1000 games on page 31
# Found 231 target games with valid data on this page
# Total collected: 15,894
# Progress: 15894/22214 (71.5%)
#
# Processing page 32...
# Got 1000 games on page 32
# Found 189 target games with valid data on this page
# Total collected: 16,018
# Progress: 16018/22214 (72.1%)
#
# Processing page 33...
# Got 1000 games on page 33
# Found 238 target games with valid data on this page
# Total collected: 16,239
# Progress: 16239/22214 (73.1%)
#
# Processing page 34...
# Got 1000 games on page 34
# Found 163 target games with valid data on this page
# Total collected: 16,402
# Progress: 16402/22214 (73.8%)
#
# Processing page 35...
# Got 1000 games on page 35
# Found 214 target games with valid data on this page
# Total collected: 16,541
# Progress: 16541/22214 (74.5%)
#
# Processing page 36...
# Got 1000 games on page 36
# Found 227 target games with valid data on this page
# Total collected: 16,687
# Progress: 16687/22214 (75.1%)
#
# Processing page 37...
# Got 1000 games on page 37
# Found 192 target games with valid data on this page
# Total collected: 16,868
# Progress: 16868/22214 (75.9%)
#
# Processing page 38...
# Got 1000 games on page 38
# Found 184 target games with valid data on this page
# Total collected: 17,004
# Progress: 17004/22214 (76.5%)
#
# Processing page 39...
# Got 1000 games on page 39
# Found 166 target games with valid data on this page
# Total collected: 17,140
# Progress: 17140/22214 (77.2%)
#
# Processing page 40...
# Got 1000 games on page 40
# Found 165 target games with valid data on this page
# Total collected: 17,256
# Progress: 17256/22214 (77.7%)
# Saved progress at page 40
#
# Processing page 41...
# Got 1000 games on page 41
# Found 147 target games with valid data on this page
# Total collected: 17,335
# Progress: 17335/22214 (78.0%)
#
# Processing page 42...
# Got 1000 games on page 42
# Found 153 target games with valid data on this page
# Total collected: 17,431
# Progress: 17431/22214 (78.5%)
#
# Processing page 43...
# Got 1000 games on page 43
# Found 261 target games with valid data on this page
# Total collected: 17,617
# Progress: 17617/22214 (79.3%)
#
# Processing page 44...
# Got 1000 games on page 44
# Found 73 target games with valid data on this page
# Total collected: 17,676
# Progress: 17676/22214 (79.6%)
#
# Processing page 45...
# Got 1000 games on page 45
# Found 119 target games with valid data on this page
# Total collected: 17,795
# Progress: 17795/22214 (80.1%)
#
# Processing page 46...
# Got 1000 games on page 46
# Found 172 target games with valid data on this page
# Total collected: 17,967
# Progress: 17967/22214 (80.9%)
#
# Processing page 47...
# Got 1000 games on page 47
# Found 67 target games with valid data on this page
# Total collected: 18,034
# Progress: 18034/22214 (81.2%)
#
# Processing page 48...
# Got 1000 games on page 48
# Found 71 target games with valid data on this page
# Total collected: 18,105
# Progress: 18105/22214 (81.5%)
#
# Processing page 49...
# Got 1000 games on page 49
# Found 229 target games with valid data on this page
# Total collected: 18,334
# Progress: 18334/22214 (82.5%)
#
# Processing page 50...
# Got 1000 games on page 50
# Found 31 target games with valid data on this page
# Total collected: 18,365
# Progress: 18365/22214 (82.7%)
#
# Processing page 51...
# Got 1000 games on page 51
# Found 62 target games with valid data on this page
# Total collected: 18,427
# Progress: 18427/22214 (83.0%)
#
# Processing page 52...
# Got 1000 games on page 52
# Found 151 target games with valid data on this page
# Total collected: 18,578
# Progress: 18578/22214 (83.6%)
#
# Processing page 53...
# Got 1000 games on page 53
# Found 146 target games with valid data on this page
# Total collected: 18,724
# Progress: 18724/22214 (84.3%)
#
# Processing page 54...
# Got 1000 games on page 54
# Found 39 target games with valid data on this page
# Total collected: 18,763
# Progress: 18763/22214 (84.5%)
#
# Processing page 55...
# Got 1000 games on page 55
# Found 54 target games with valid data on this page
# Total collected: 18,817
# Progress: 18817/22214 (84.7%)
#
# Processing page 56...
# Got 1000 games on page 56
# Found 6 target games with valid data on this page
# Total collected: 18,823
# Progress: 18823/22214 (84.7%)
#
# Processing page 57...
# Got 1000 games on page 57
# Found 140 target games with valid data on this page
# Total collected: 18,963
# Progress: 18963/22214 (85.4%)
#
# Processing page 58...
# Got 1000 games on page 58
# Found 99 target games with valid data on this page
# Total collected: 19,062
# Progress: 19062/22214 (85.8%)
#
# Processing page 59...
# Got 1000 games on page 59
# Found 53 target games with valid data on this page
# Total collected: 19,115
# Progress: 19115/22214 (86.0%)
#
# Processing page 60...
# Got 1000 games on page 60
# Found 18 target games with valid data on this page
# Total collected: 19,133
# Progress: 19133/22214 (86.1%)
# Saved progress at page 60
#
# Processing page 61...
# Got 1000 games on page 61
# Found 77 target games with valid data on this page
# Total collected: 19,210
# Progress: 19210/22214 (86.5%)
#
# Processing page 62...
# Got 1000 games on page 62
# Found 0 target games with valid data on this page
# Total collected: 19,210
# Progress: 19210/22214 (86.5%)
#
# Processing page 63...
# Got 1000 games on page 63
# Found 3 target games with valid data on this page
# Total collected: 19,213
# Progress: 19213/22214 (86.5%)
#
# Processing page 64...
# Got 1000 games on page 64
# Found 112 target games with valid data on this page
# Total collected: 19,325
# Progress: 19325/22214 (87.0%)
#
# Processing page 65...
# Got 1000 games on page 65
# Found 79 target games with valid data on this page
# Total collected: 19,404
# Progress: 19404/22214 (87.4%)
#
# Processing page 66...
# Got 1000 games on page 66
# Found 62 target games with valid data on this page
# Total collected: 19,466
# Progress: 19466/22214 (87.6%)
#
# Processing page 67...
# Got 1000 games on page 67
# Found 10 target games with valid data on this page
# Total collected: 19,476
# Progress: 19476/22214 (87.7%)
#
# Processing page 68...
# Got 1000 games on page 68
# Found 12 target games with valid data on this page
# Total collected: 19,488
# Progress: 19488/22214 (87.7%)
#
# Processing page 69...
# Got 1000 games on page 69
# Found 9 target games with valid data on this page
# Total collected: 19,497
# Progress: 19497/22214 (87.8%)
#
# Processing page 70...
# Got 1000 games on page 70
# Found 70 target games with valid data on this page
# Total collected: 19,567
# Progress: 19567/22214 (88.1%)
#
# Processing page 71...
# Got 1000 games on page 71
# Found 0 target games with valid data on this page
# Total collected: 19,567
# Progress: 19567/22214 (88.1%)
#
# Processing page 72...
# Got 1000 games on page 72
# Found 0 target games with valid data on this page
# Total collected: 19,567
# Progress: 19567/22214 (88.1%)
#
# Processing page 73...
# Got 1000 games on page 73
# Found 7 target games with valid data on this page
# Total collected: 19,574
# Progress: 19574/22214 (88.1%)
#
# Processing page 74...
# Got 1000 games on page 74
# Found 2 target games with valid data on this page
# Total collected: 19,576
# Progress: 19576/22214 (88.1%)
#
# Processing page 75...
# Got 1000 games on page 75
# Found 332 target games with valid data on this page
# Total collected: 19,908
# Progress: 19908/22214 (89.6%)
#
# Processing page 76...
# Got 1000 games on page 76
# Found 81 target games with valid data on this page
# Total collected: 19,989
# Progress: 19989/22214 (90.0%)
#
# Processing page 77...
# Got 1000 games on page 77
# Found 105 target games with valid data on this page
# Total collected: 20,094
# Progress: 20094/22214 (90.5%)
#
# Processing page 78...
# Got 1000 games on page 78
# Found 43 target games with valid data on this page
# Total collected: 20,137
# Progress: 20137/22214 (90.7%)
#
# Processing page 79...
# Got 1000 games on page 79
# Found 35 target games with valid data on this page
# Total collected: 20,172
# Progress: 20172/22214 (90.8%)
#
# Processing page 80...
# Got 1000 games on page 80
# Found 3 target games with valid data on this page
# Total collected: 20,175
# Progress: 20175/22214 (90.8%)
# Saved progress at page 80
#
# Processing page 81...
# Got 1000 games on page 81
# Found 9 target games with valid data on this page
# Total collected: 20,184
# Progress: 20184/22214 (90.9%)
#
# Processing page 82...
# Got 1000 games on page 82
# Found 15 target games with valid data on this page
# Total collected: 20,199
# Progress: 20199/22214 (90.9%)
#
# Processing page 83...
# Got 1000 games on page 83
# Found 2 target games with valid data on this page
# Total collected: 20,201
# Progress: 20201/22214 (90.9%)
#
# Processing page 84...
# Got 1000 games on page 84
# Found 4 target games with valid data on this page
# Total collected: 20,205
# Progress: 20205/22214 (91.0%)
#
# Processing page 85...
# Got 1000 games on page 85
# Found 76 target games with valid data on this page
# Total collected: 20,281
# Progress: 20281/22214 (91.3%)
#
# Processing page 86...
# Got 537 games on page 86
# Found 24 target games with valid data on this page
# Total collected: 20,305
# Progress: 20305/22214 (91.4%)
#
# Processing page 87...
# HTTP 500 on page 87
#
# === COLLECTION COMPLETE ===
# Pages processed: 87
# Games collected: 20,305
# Target games found: 20,305/22,214
# Final coverage: 91.4%

# %% [markdown]
# # Further Data Cleaning for Item Sparse Matrix Later

# %%
# Further Data Cleaning for Item-Based Sparse Matrix
if full_data:
    print(f"\nCollection successful: {len(full_data):,} games with metadata")
    
    # Clean dataset for item-based recommendations
    print("\nCreating clean dataset for item-based collaborative filtering")
    
    # Convert SteamSpy data to DataFrame
    steamspy_df = pd.DataFrame.from_dict(full_data, orient='index')
    steamspy_df = steamspy_df.reset_index()
    steamspy_df = steamspy_df.rename(columns={'index': 'app_id'})
    steamspy_df['app_id'] = steamspy_df['app_id'].astype(int)
    
    print(f"SteamSpy DataFrame shape: {steamspy_df.shape}")
    
    # Define essential columns for item-based recommendations
    essential_columns = ['app_id', 'name', 'developer', 'publisher']
    
    # Keep all available columns that might be useful
    available_cols = [col for col in essential_columns if col in steamspy_df.columns]
    steamspy_clean = steamspy_df[available_cols].copy()
    
    print(f"Available metadata columns: {available_cols}")
    
    # Filter interactions and merge with metadata
    print(f"\nFiltering and merging data for item-based system...")
    
    # Only keep games that have complete metadata
    games_with_metadata = set(steamspy_clean['app_id'].unique())
    print(f"Games with SteamSpy metadata: {len(games_with_metadata):,}")
    
    # Filter recommendations to only include games with metadata
    rec_filtered = rec[rec['app_id'].isin(games_with_metadata)].copy()
    print(f"Interactions with metadata: {len(rec_filtered):,} (was {len(rec):,})")
    print(f"Reduction: {len(rec) - len(rec_filtered):,} interactions removed")
    
    # Re-apply filtering after metadata merge (some games might have been lost)
    print(f"\nRe-applying user/game thresholds after metadata filtering...")
    
    # Filter 1: Remove users with too few games (after metadata filtering)
    min_user_games = 5
    post_metadata_user_activity = rec_filtered['user_id'].value_counts()
    active_users = post_metadata_user_activity[post_metadata_user_activity >= min_user_games].index
    rec_filtered = rec_filtered[rec_filtered['user_id'].isin(active_users)]
    print(f"Users after {min_user_games}+ games filter: {rec_filtered['user_id'].nunique():,}")
    
    # Filter 2: Remove unpopular games (after user filtering)
    min_game_users = 15
    post_user_filter_game_popularity = rec_filtered['app_id'].value_counts()
    popular_games = post_user_filter_game_popularity[post_user_filter_game_popularity >= min_game_users].index
    rec_filtered = rec_filtered[rec_filtered['app_id'].isin(popular_games)]
    print(f"Games after {min_game_users}+ users filter: {rec_filtered['app_id'].nunique():,}")
    
    # Merge with metadata (inner join for complete data only)
    rec_enhanced = rec_filtered.merge(
        steamspy_clean,
        on='app_id',
        how='inner'  # Only keep games with complete metadata
    )
    
    # Final data quality cleaning
    print(f"\nFinal data quality cleaning...")
    before_cleaning = len(rec_enhanced)
    
    # Remove rows where essential data is missing or empty
    rec_enhanced = rec_enhanced[rec_enhanced['name'].notna()]
    rec_enhanced = rec_enhanced[rec_enhanced['name'].str.strip() != '']
    
    if 'developer' in rec_enhanced.columns:
        rec_enhanced = rec_enhanced[rec_enhanced['developer'].notna()]
        rec_enhanced = rec_enhanced[rec_enhanced['developer'].str.strip() != '']
    
    after_cleaning = len(rec_enhanced)
    print(f"Removed {before_cleaning - after_cleaning:,} rows with missing essential data")
    
    # Final statistics optimized for item-based filtering
    print(f"\nFINAL CLEAN DATASET STATISTICS (Item-Based Ready):")
    print(f"Total interactions: {len(rec_enhanced):,}")
    print(f"Unique users: {rec_enhanced['user_id'].nunique():,}")
    print(f"Unique games: {rec_enhanced['app_id'].nunique():,}")
    print(f"Average games per user: {len(rec_enhanced) / rec_enhanced['user_id'].nunique():.1f}")
    print(f"Average users per game: {len(rec_enhanced) / rec_enhanced['app_id'].nunique():.1f}")
    print(f"Data completeness: 100% (all rows have metadata)")
    
    # Calculate sparsity for item-based matrix (games × users)
    n_games = rec_enhanced['app_id'].nunique()
    n_users = rec_enhanced['user_id'].nunique()
    sparsity = (1 - len(rec_enhanced) / (n_games * n_users)) * 100
    print(f"Matrix sparsity: {sparsity:.2f}% (Item-User matrix: {n_games:,} × {n_users:,})")
    
    # Memory estimation for item-user sparse matrix
    estimated_sparse_mb = (len(rec_enhanced) * 12) / (1024**2)  # 12 bytes per nnz element in CSR
    print(f"Estimated sparse matrix memory: ~{estimated_sparse_mb:.1f} MB")
    
    # Show sample of clean data
    print(f"\nSample clean data for item-based recommendations:")
    display_cols = ['user_id', 'app_id', 'name', 'developer']
    available_display_cols = [col for col in display_cols if col in rec_enhanced.columns]
    print(rec_enhanced[available_display_cols].head())
    
    # Save datasets optimized for item-based collaborative filtering
    print(f"\nSaving clean datasets for item-based system...")
    
    # 1. Core interaction data for sparse matrix creation (MOST IMPORTANT)
    interaction_data = rec_enhanced[['user_id', 'app_id']].copy()
    # Add implicit rating (1 = user played this game)
    interaction_data['rating'] = 1
    interaction_data.to_csv('../data/clean_interactions.csv', index=False)
    print("Saved: clean_interactions.csv (Ready for sparse matrix creation)")
    
    # 2. Game metadata for recommendation display
    game_metadata = rec_enhanced[available_cols].drop_duplicates(subset=['app_id']).copy()
    game_metadata = game_metadata.sort_values('app_id').reset_index(drop=True)
    game_metadata.to_csv('../data/game_metadata.csv', index=False)
    print("Saved: game_metadata.csv")
    
    # 3. Full enhanced dataset (backup)
    rec_enhanced.to_csv('../data/recommendations_enhanced.csv', index=False)
    print("Saved: recommendations_enhanced.csv (Complete dataset backup)")
    
    # 4. Save the raw SteamSpy data for future use
    with open('../data/steamspy_collected_data.json', 'w') as f:
        json.dump(full_data, f, indent=2)
    print("Saved: steamspy_collected_data.json (Raw API data)")
    
    # Summary for next steps
    print(f"clean_interactions.csv contains {len(interaction_data):,} user-game-rating tuples")
    print(f"Matrix dimensions will be: {n_games:,} games × {n_users:,} users")
    print(f"Estimated memory usage: ~{estimated_sparse_mb:.1f} MB (sparse)")
    print(f"All metadata is complete for human-readable recommendations")
    
    # Update the main rec DataFrame
    rec = rec_enhanced.copy()
else:
    print("Collection failed - cannot proceed with matrix creation")
# Out:
# Collection successful: 20,305 games with metadata
#
# Creating clean dataset for item-based collaborative filtering
# SteamSpy DataFrame shape: (20305, 18)
# Available metadata columns: ['app_id', 'name', 'developer', 'publisher']
#
# Filtering and merging data for item-based system...
# Games with SteamSpy metadata: 20,305
# Interactions with metadata: 17,582,388 (was 17,950,499)
# Reduction: 368,111 interactions removed
#
# Re-applying user/game thresholds after metadata filtering...
# Users after 5+ games filter: 1,579,456
# Games after 15+ users filter: 20,209
#
# Final data quality cleaning...
# Removed 9,888 rows with missing essential data
#
# FINAL CLEAN DATASET STATISTICS (Item-Based Ready):
# Total interactions: 17,398,025
# Unique users: 1,579,456
# Unique games: 20,156
# Average games per user: 11.0
# Average users per game: 863.2
# Data completeness: 100% (all rows have metadata)
# Matrix sparsity: 99.95% (Item-User matrix: 20,156 × 1,579,456)
# Estimated sparse matrix memory: ~199.1 MB
#
# Sample clean data for item-based recommendations:
#    user_id   app_id                                        name  \
# 0    51580   975370                              Dwarf Fortress
# 1   161081  1938090             Call of Duty: Modern Warfare II
# 2    76583   635260                    CarX Drift Racing Online
# 3   664486  1938090             Call of Duty: Modern Warfare II
# 4    22793   534380  Dying Light 2 Stay Human: Reloaded Edition
#
#                                            developer
# 0                                       Bay 12 Games
# 1  Treyarch, Raven Software, Beenox, High Moon St...
# 2                             CarX Technologies, LLC
# 3  Treyarch, Raven Software, Beenox, High Moon St...
# 4                                           Techland
#
# Saving clean datasets for item-based system...
# Saved: clean_interactions.csv (Ready for sparse matrix creation)
# Saved: game_metadata.csv
# Saved: recommendations_enhanced.csv (Complete dataset backup)
# Saved: steamspy_collected_data.json (Raw API data)
# clean_interactions.csv contains 17,398,025 user-game-rating tuples
# Matrix dimensions will be: 20,156 games × 1,579,456 users
# Estimated memory usage: ~199.1 MB (sparse)
# All metadata is complete for human-readable recommendations
